# %%
import pypsa
import numpy as np
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12,8))

# Read in solved network
network = pypsa.Network("results/networks/test/elec_s_10_ec_lcopt_Ep-1H.nc")
